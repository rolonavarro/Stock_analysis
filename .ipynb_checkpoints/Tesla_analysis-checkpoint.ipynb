# %%
# Import tesla data for the last two year Date(From: 04/07/2020 To: 04/07/2018)
import datetime as dt
import matplotlib.pyplot as plt
from matplotlib import style
import pandas as pd
import pandas_datareader.data as web

style.use('ggplot')

# Read csv file. The making the date to be the index
df = pd.read_csv("DATA/TSLA.csv", parse_dates=True, index_col=0)
df.head()

# %%
change = (df["Open"] - df["Close"])/df["Open"]
df["Change"] = change
df.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-04-09  300.369995  309.500000  289.209991  289.660004  289.660004
# 2018-04-10  298.970001  307.100006  293.679993  304.700012  304.700012
# 2018-04-11  300.739990  308.980011  299.660004  300.929993  300.929993
# 2018-04-12  302.320007  303.950012  293.679993  294.079987  294.079987
# 2018-04-13  303.600006  303.950012  295.980011  300.339996  300.339996
#
#               Volume    Change
# Date
# 2018-04-09  10249800  0.035656
# 2018-04-10  10989800 -0.019166
# 2018-04-11   7482900 -0.000632
# 2018-04-12   7608800  0.027256
# 2018-04-13   7327200  0.010738

# %%
# Adjusted Price
df['Adj Close'].plot()

# %%
# Volatility of the price in Tesla
df['Change'].plot()
